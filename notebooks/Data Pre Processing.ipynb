# %% [markdown]
# # Data Pre Processing
#
# After viewing our EDA we will be needing to create a few modifications to our data set in order to prepare it for our modeling.

# %%
import pandas as pd
import numpy as np
datafile = pd.read_csv("../data/processed/fires.csv")

# %% [markdown]
# Due to the column "month" being a string we will need to drop it for our linear regression. The Linear Regression will need to convert the values into floats and strings cannot be converted to floats.

# %%
df_processed = datafile.drop("month", axis= 1)
df_processed
# Out:
#      FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..    ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 9 columns]

# %% [markdown]
# # Transforming the area output
#
# Considering that the area output is heavily skewed to values of 0.0 which may turn the data in the column "area" unfit for the linear regression, we transform the column with a ln(x+1) function

# %%
df_processed['area'] = np.log1p(df_processed['area'])

# %%
# save data for later modeling
df_processed.to_csv("../data/processed/processed_fires.csv", index= False)
