# %%
import pandas as pd

datafile = pd.read_excel(r"C:\Users\neves\Downloads\energy+efficiency\data\raw\ENB2012_data.xlsx")

# %% [markdown]
# In this step I renamed the columns according to its descriptive equivalent according to the data set instructions: https://archive.ics.uci.edu/dataset/242/energy+efficiency

# %%
datafile.rename(columns= {"X1" : "Relative Compactness", 
                          "X2" : "Surface Area", 
                          "X3" : "Wall Area", 
                          "X4" : "Roof Area", 
                          "X5" : "Overall Height", 
                          "X6" : "Orientation", 
                          "X7" : "Glazing Area", 
                          "X8" : "Glazing Area Distribution", 
                          "Y1" : "Heating Load", 
                          "Y2" : "Cooling Load" },   inplace= True)

# %% [markdown]
# Objectives
#
# How can we classify the different buildings?
# Are there any errors, outliers, and other issues with the data?
# What are some initial trends that might be interesting to pursue?
# What are some potentially useful features?

# %%
datafile.hist("Relative Compactness")
# Out:
# array([[<Axes: title={'center': 'Relative Compactness'}>]], dtype=object)
